# %%
from kolos_lib import *

ARBUZY = [4.5 , 4.5 , 4.9 , 6.3 , 3.3 , 6.3 , 3.9 , 4.3 , 4.5 , 3.5 , 3.2 , 5 , 5.4 , 4.6 , 4.2 , 5.7 , 4.7 , 5.7 , 4.6 , 4.4 , 5.5 , 4.9 , 4.1 , 3.9 , 4.6 , 4.9 , 4.4 , 5.7 , 6.1 , 5.9 , 4.5 , 4.7 , 5 , 3.1 , 4.6 , 4.9 , 6.2 , 6.2 , 5.7 , 5.1]
MIASTO =[10,27,29,16,8,7]
PRZED = [95.5, 98.7, 90.4, 115.9, 104.0, 85.6]
PO = [93.9, 97.4, 91.7, 112.8, 101.3, 84.0]

# %%
generator_kos(8, 20, 2456)
# Out:
# [1, 1, 2, 16, 9, 10, 16, 11]

# %%
print(hipoteza_zmienne_zalezne(PRZED, PO, 2, 0.05, 'L'))
print(hipoteza_zmienne_zalezne(PRZED, PO, 2, 0.01, 'L'))
# Out:
# True
# True

# %%
print(hipoteza_srednia(ARBUZY, 5,0.05, typ_hipotezy='P'))
print(hipoteza_srednia(ARBUZY, 5,0.01, typ_hipotezy='P'))
# Out:
# True
# True

# %%
n = 24.6 * 10 ** 6

print(CTG(n, 0, 100, gora = -0.03*n))
print(CTG(n, 0, 100, gora = -0.01*n))
# Out:
# 0.0683818274976584
# 0.30995289538374765

# %%
print(spr_poisson(MIASTO, 1, 0.05))
print(spr_poisson(MIASTO, 2, 0.05))
# Out:
# False
# True
