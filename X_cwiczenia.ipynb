# %%
from kolos_lib import *

# %%
n = 100_000
p = 0.001 * 0.1 * 0.5

print(poisson_ext(n, p, [0,1,2,3]))
# Out:
# (0.2650259152973617, 0.00025)

# %%
n = 1
p = 1

print(poisson(n, p, 0))
# Out:
# 0.36787944117144233

# %%
n = 1
p = 1
result = 0

for k in range(200):
    result += poisson(n, p, k) ** 2

print(result > 0.5)
# Out:
# False

# %%
n = 1000
a = 3450
b = 3550
mu = 3.5
sigma = math.sqrt(91/6 - 3.5**2)
alfa = 0.01

DUMMY_DANE = [mu * n] * n

print(CTG(n, 3.5, sigma, a, b))
print(esty_sr(DUMMY_DANE, sigma * n, alfa))
# Out:
# 0.6454605202264987
# (3360.889318336159, 3639.110681663841)

# %%
n = 400
sigma = 100
alfa = 0.01
