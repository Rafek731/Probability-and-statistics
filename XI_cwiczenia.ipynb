# %%
from kolos_lib import *

# %% [markdown]
# ### Zadanie 1

# %%
n = 81
x_bar = 680
sigma = 270
alfa = 0.05

SPRZEDAZE = [x_bar] * n

esty_sr(SPRZEDAZE, sigma, alfa)
# Out:
# (621.2010804637983, 738.7989195362017)

# %%
n = 36
x_bar = 139_000
sigma = 12_000
alfa_a = 0.05
alfa_b = 0.01

DANE = [x_bar] * n

print(esty_sr(DANE, sigma, alfa_a))
print(esty_sr(DANE, sigma, alfa_b))
# Out:
# (135080.0720309199, 142919.9279690801)
# (133848.3413929022, 144151.6586070978)

# %%
KINESKOPY = [8.1, 7.9, 9.6, 6.4, 8.7, 8.8, 7.9]
alfa = 0.1

print(esty_sr_bez_od(KINESKOPY, alfa))
# Out:
# (7.46554688931311, 8.934453110686889)

# %%
GODZINY = [8 , 12 , 26 , 10 , 23 , 21 , 16 , 22 , 18 , 17 , 36 , 9]
alfa = 0.01

print(esty_sr_bez_od(GODZINY, alfa))
# Out:
# (10.89461902437121, 25.438714308962126)

# %%
BATERIE = [5, -4 , 10 , 15 , 11 , 25 , -5 , 17 , -5 , 0 , 8 , 12 , 14 , 8 , 1 , 5]
alfa = 0.05

print(esty_sr_bez_od(BATERIE, alfa))
# Out:
# (2.7713003469918416, 11.853699653008158)

# %%
n = 169
zapamietalo = 48
SLUCHACZE = [1] * zapamietalo + [0] * (n - zapamietalo)
alfa = 0.1

esty_prop(SLUCHACZE, 1, alfa)
# Out:
# (0.22696646229980366, 0.34108087497830286)

# %%
import pandas as pd
alfa = 0.05

dane = pd.read_csv('Per.csv', sep=';')
kobiety = esty_war(dane['sister'].to_numpy(), alfa)
mezczyzni = esty_war(dane['brother'].to_numpy(), alfa)
razem = esty_war(list(dane['sister']) + list(dane['brother']), alfa)

print(f"{kobiety=} {mezczyzni=} {razem=}")
# Out:
# kobiety=(3.2221563515095215, 20.326625588523047) mezczyzni=(3.6127207577530998, 22.79045899319251) razem=(7.8215555852829, 26.986556306301882)

# %%
dane = pd.read_csv('App.csv', sep=';')
alfa = 0.01

print(esty_war(dane['cost'].to_numpy(dtype=int), alfa))
# Out:
# (739169.7142339855, 1944773.4282133786)

# %%
dane = pd.read_csv('Famn.csv', sep=';')
alfa = 0.05

print(esty_war(dane['cost'].to_numpy(), alfa))
# Out:
# (22.792906059640224, 84.07327393536298)
